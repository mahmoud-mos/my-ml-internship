# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mahmoud-mos/my-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why\n\nI have chosen
# **Lane 2: Refresh / Content Opportunity Scoring**.
# This lane focuses on prioritizing high-visibility content assets that are actively decaying or stale. As the inventory of content grows, manually identifying which pages require updates becomes inefficient. By using a data-driven approach to rank content, we can provide actionable insights for an editor, allowing them to focus their limited time on the content with the highest potential impact.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd
df = pd.read_csv('../../data/raw/content_refresh_anonymized.csv')
print("Dataset Shape:", df.shape)
# Out:
# Dataset Shape: (30000, 44)

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# We are supporting the **decision** of which content assets to prioritize for manual review and refresh. An **editor** acts on this output by reviewing and updating the top-ranked assets. A **wrong recommendation** (false positive) results in wasted editor time spent on content that did not require a refresh, while a missed opportunity (false negative) results in a failure to arrest the decline of a high-visibility asset. Data/ML is required here because manually scanning and evaluating thousands of content items for decay patterns is infeasible; a ranked, prioritized queue transforms a massive, unmanageable inventory into a focused daily task list.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Trend Direction Counts:")
print(df['trend_direction'].value_counts())
# Out:
# Trend Direction Counts:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# To justify our focus on stale content, we examined our starter dataset of 30,000 items. We found that a significant portion of our inventory is stale (defined as not updated in 180+ days), and a subset of those items still generate substantial impressions. This proves that an automated prioritization queue is necessary to help editors identify which of these stale assets deserve immediate attention.

# %%
import pandas as pd

# Load the data
df = pd.read_csv('../../data/raw/content_refresh_anonymized.csv')

# Define the stale threshold and high-visibility threshold
stale_days = 180
min_impressions = 500

# Calculate the numbers
stale_assets = df[df['days_since_last_update'] >= stale_days]
stale_high_vis = stale_assets[stale_assets['impressions_90d'] >= min_impressions]

print(f"Total content items: {len(df)}")
print(f"Stale assets (>= {stale_days} days): {len(stale_assets)}")
print(f"High-visibility stale assets (>= {min_impressions} impressions): {len(stale_high_vis)}")
# Out:
# Total content items: 30000
# Stale assets (>= 180 days): 174
# High-visibility stale assets (>= 500 impressions): 17

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# This work provides **decision-support** and **directional** guidance for content editors. We can observe correlations between content age and traffic decay in our dataset; however, we **do not claim causal proof** that refreshing a specific page will directly cause a recovery in traffic. Our results measure the *potential* impact of updates based on historical patterns, not a guarantee of future search engine performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print(df[['days_since_last_update', 'impressions_90d', 'clicks_90d']].describe())
# Out:
#        days_since_last_update  impressions_90d    clicks_90d
# count            30000.000000     30000.000000  30000.000000
# mean                46.098300      5200.366300     16.097333
# std                 42.078709     16838.019547     75.076958
# min                  1.000000         1.000000      0.000000
# 25%                 20.000000        81.000000      0.000000
# 50%                 20.000000       731.000000      1.000000
# 75%                104.000000      3615.250000      7.000000
# max                373.000000    517715.000000   4178.000000

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
